# %%
import numpy as np
import pandas as pd
from src.decision_tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor as DTR
from sklearn.metrics import RMSE

# %% [markdown]
# # Decision Tree

# %%
df_train = pd.read_csv("D:\CS115\CS115_Trees\data\ train.csv")
df_test = pd.read_csv("D:\CS115\CS115_Trees\data\ test.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\NGHIA\AppData\Local\Temp\ipykernel_9416\1216259335.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df_train = pd.read_csv("D:\CS115\CS115_Trees\data\ train.csv")
# C:\Users\NGHIA\AppData\Local\Temp\ipykernel_9416\1216259335.py:2: SyntaxWarning: invalid escape sequence '\C'
#   df_test = pd.read_csv("D:\CS115\CS115_Trees\data\ test.csv")

# %%
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:, -1].values

# %% [markdown]
# ## Decision Tree from scratch

# %%
model = DecisionTreeRegressor()
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
def RMSE(y_true, y_pred):
    squared_errors = (y_true - y_pred) ** 2
    mse = np.mean(squared_errors)
    rmse_value = np.sqrt(mse)
    
    return rmse_value

# %%
RMSE(y_test, y_pred)
# Out:
# np.float64(17.596417892307993)

# %% [markdown]
# ## Decision Tree with Scikit-Learn

# %%
sk_model = DTR()
sk_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sk_model = DTR()
#       2 sk_model.fit(X_train, y_train)
#
# NameError: name 'DTR' is not defined

# %%
y_pred = sk_model.predict(X_test)

# %%
RMSE(y_test, y_pred)
# Out:
# np.float64(5.22095138201203)

# %% [markdown]
# # Random_forest

# %%
from src.random_forest import RandomForestRegressor
import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv("F:\CS115\CS115_Trees\data\ train.csv")
df_test = pd.read_csv("F:\CS115\CS115_Trees\data\ test.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\HP\AppData\Local\Temp\ipykernel_9552\402617650.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df_train = pd.read_csv("F:\CS115\CS115_Trees\data\ train.csv")
# C:\Users\HP\AppData\Local\Temp\ipykernel_9552\402617650.py:2: SyntaxWarning: invalid escape sequence '\C'
#   df_test = pd.read_csv("F:\CS115\CS115_Trees\data\ test.csv")

# %%
X_train, y_train = df_train.iloc[:, :-1].values, df_train.iloc[:, -1].values
X_test, y_test = df_test.iloc[:, :-1].values, df_test.iloc[:, -1].values

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
def RMSE(y_true, y_pred):
    squared_errors = (y_true - y_pred) ** 2
    mse = np.mean(squared_errors)
    rmse_value = np.sqrt(mse)
    
    return rmse_value

# %%
RMSE(y_test, y_pred)
# Out:
# 12.975730396982476
